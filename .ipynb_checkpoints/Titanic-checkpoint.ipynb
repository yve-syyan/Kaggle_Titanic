# %% [markdown]
# # Kaggle Titanic Data Challenge
#
# This notebook performs predictive machine learning modeling on the Titanic survival dataset from [Kaggle](https://www.kaggle.com/c/titanic). The goal is to predict if a passgener will be able to survived.
#
# Below I have performed descriptive data analysis, data preprocessing, feature engineering and feature extraction. I trained models using SVM, Naive Bayes, K-Nearest Neighbors, Decision Tree, Random Forest and implemented hyptertuning using GridSearch. After benchmarking the results from all models, I trained test data using Random Forest. The final submission reached 0.7894 accuracy, scoring top 12% on Kaggle leaderboard.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Import data from local files

# %%
train = pd.read_csv("data/train.csv",index_col='PassengerId')
test = pd.read_csv("data/test.csv",index_col='PassengerId')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 123.5+ KB

# %% [markdown]
# The training dataset contains 891 entries, 1 target features and 10 predictive features. They are:
#
# | Variable | Definition | Key |
# |:----------:|:------------:|:------------:|
# | survival | Survival |0 = No, 1 = Yes|
# |pclass|Ticket class|1 = 1st, 2 = 2nd, 3 = 3rd|
# |sex|Sex||
# |sibsp|# of siblings / spouses aboard the Titanic	| |
# |parch|# of parents / children aboard the Titanic| |
# |ticket|Ticket number| |
# |fare|Passenger fare| |
# |cabin|Cabin number| |
# |embarked|Port of Embarkation| C = Cherbourg, Q = Queenstown, S = Southampton|

# %% [markdown]
# ## Descriptive Data Analysis and Visualizations

# %% [markdown]
# The following section explores data distribution, correlation using visualization.

# %% [markdown]
# ### Class Level and Survival Rate

# %%
fig,axes = plt.subplots(nrows=1, ncols=2, sharex='col', sharey='row', figsize=(10,4))
pclass_mean = sns.barplot(x='Pclass',y='Survived',ax=axes[0],data = train, palette='coolwarm')
pclass_mean.set_title("Mean")

pclass_var = sns.barplot(x='Pclass',y='Survived',ax=axes[1],data = train, palette='coolwarm',estimator=np.std)
pclass_var.set_title("Standard Deviation")
fig.suptitle("Pclass VS Survival Rate")
# Out:
# Text(0.5, 0.98, 'Pclass VS Survival Rate')

# %% [markdown]
# Higher class level corresponds to a higher survival rate.

# %% [markdown]
# ### Gender, Class Level and Survival Rate

# %%
g = sns.catplot(x="Pclass", hue="Survived", col="Sex",
                data=train, kind="count",
                palette='coolwarm')
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle("Gender, Class and Survival Rate")
# Out:
# Text(0.5, 0.98, 'Gender, Class and Survival Rate')

# %% [markdown]
# The previous conclusion that survival rate drops as class level increases is valid for both female and male passengers. Moreover, female passengers have higher survival rate than male in all classes.

# %% [markdown]
# ### Port of Embarkation and Survival Rate

# %%
fig,axes = plt.subplots(nrows=1, ncols=2, sharex='col', sharey='row', figsize=(10,4))
embarked_mean = sns.barplot(x='Embarked',y='Survived',ax=axes[0],data = train, palette='coolwarm')
embarked_mean.set_title("Embarked Mean")

embarked_var = sns.barplot(x='Embarked',y='Survived',ax=axes[1],data = train, palette='coolwarm',estimator=np.std)
embarked_var.set_title("Embarked Variance")
fig.suptitle("Port of Embarkation VS Survival Rate")
# Out:
# Text(0.5, 0.98, 'Port of Embarkation VS Survival Rate')

# %% [markdown]
# Passengers embarked on Cherbourg has the highest survival rate, followed by those embarked on Queenstown.

# %% [markdown]
# ### Gender, Port of Embarkation and Survival Rate

# %%
g = sns.catplot(x="Embarked", hue="Survived", col="Sex",
                data=train, kind="count",
                palette='coolwarm')
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle("Gender, Port of Embarkation and Survival Rate")
# Out:
# Text(0.5, 0.98, 'Gender, Port of Embarkation and Survival Rate')

# %% [markdown]
# Male passengers embarked on Cherbourg have higher chance of survival.
# Female passengers embarked on Southampton have higher chance of survival.

# %% [markdown]
# ### Gender, Age and Survival Rate

# %%
fig,axes = plt.subplots(nrows=1, ncols=2, sharex='col', sharey='row', figsize=(10,4))

male =train[train['Sex']=='male']
ax_m = sns.distplot(male[male['Survived']==0]['Age'],label="not_survived",ax=axes[0],kde=False,bins=50)
ax_m = sns.distplot(male[male['Survived']==1]['Age'],label="survived",ax=axes[0],kde=False,bins=50)
ax_m.set_title("Male")
ax_m.legend()

female = train[train['Sex']=='female']
ax_f = sns.distplot(female[female['Survived']==0]['Age'],label="not_survived",ax=axes[1],kde=False,bins=50)
ax_f = sns.distplot(female[female['Survived']==1]['Age'],label="survived",ax=axes[1],kde=False,bins=50)
ax_f.set_title("Female")
ax_f.legend()
fig.suptitle("Gender, Age and Survival Rate")
# Out:
# Text(0.5, 0.98, 'Gender, Age and Survival Rate')

# %% [markdown]
# Male passengers in age 30-40 have higher survival rate.
# Female passengers in age 18-40 have higher survival rate. Also, more female (age 50+) survived than male.
# Both female and male children (age under 10) are likely to survive.

# %% [markdown]
# ### Number of Accompanies and Survival Rate

# %% [markdown]
# As the Sibsp and Parch columns both represent a passenger's number of accompanies, I created an additional column as the sum of Sibsp and Parch to see if there is a correlation between number of passengers traveling alone and survival rate.

# %%
# add additional column for total number of accompanies
def create_accompanies_num(train,test):
    combine = [train,test]
    for df in combine:    
        df['accompanies_num'] = df['SibSp']+df['Parch']
        df['Is_Alone'] = np.where(df['accompanies_num']==0, 1, 0)
        df['Is_Alone'].value_counts()
        df.drop(['SibSp','Parch'],axis=1,inplace=True)
    return train,test

# %%
train,test = create_accompanies_num(train,test)

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(x='accompanies_num',hue='Survived',data=train,palette='coolwarm')
ax.set_title("Number of Accompanies and Survival Rate")
ax.legend(loc='upper right')

# %% [markdown]
# Passengers traveling with 1 to 3 accompanies have higher survival rate. As a trend exists the total number of accompanies and survival rate, I will keep this column for upcoming model training.

# %% [markdown]
# ## Data Preprocessing and More Visualizations

# %% [markdown]
# We start by counting missing values in all features.

# %%
number = train.isnull().sum(axis=0)
percentage = round(number/train.isnull().count(),3)*100
null_count = pd.concat([number,percentage],axis=1,keys=['Total','Percentage'])
null_count
# Out:
#           Total  Percentage
# Survived      0         0.0
# Pclass        0         0.0
# Name          0         0.0
# Sex           0         0.0
# Age         177        19.9
# SibSp         0         0.0
# Parch         0         0.0
# Ticket        0         0.0
# Fare          0         0.0
# Cabin       687        77.1
# Embarked      2         0.2

# %% [markdown]
# As 'Embarked' only contains 2 missing values, these rows can be safely removed.

# %%
train = train.dropna(axis=0, subset=['Embarked'])
test = test.dropna(axis=0, subset=['Embarked'])

# %% [markdown]
# The Cabin column contains more than 75% missing values, I need to determine if discernible trend between cabin level and survival rate to decide if this feature can be safely dropped.

# %%
#extract cabin level out of cabin number
def Add_Cabin_Level(train,test):
    combine = [train,test]
    for df in combine:
        df['Cabin_Level'] = df['Cabin'].str[:1]
        df['Cabin_Level']=df['Cabin_Level'].fillna('None')
        df['Cabin_Level'].value_counts()
        df=df.drop(['Cabin'],axis=1,inplace=True)
    return train,test

# %%
train,test = Add_Cabin_Level(train,test)

# %%
sns.countplot(x='Cabin_Level',hue='Survived',data = train,palette='coolwarm')

# %%
sns.boxplot(x='Pclass',y='Age',data=train,palette='coolwarm')

# %% [markdown]
# Different classes have different age distribution, people in third class tend to be younger. Generate missing values in age based on mean,std from existing columns within the same class

# %%
for (i,df) in enumerate(combine):    
    df_class_agemean=df.groupby('Pclass').mean()['Age']
    df_class_agestd=df.groupby('Pclass').std()['Age']
    df_agena=df.Age.isnull().groupby(df['Pclass']).sum()
    if i==0:
        df_class_train = pd.concat([df_class_agemean,df_class_agestd,df_agena],axis=1)
        df_class_train.columns=['mean','std','na_num']
    else:
        df_class_test = pd.concat([df_class_agemean,df_class_agestd,df_agena],axis=1)
        df_class_test.columns=['mean','std','na_num']

# %%
def generate_age(row,df_class):
    if pd.isnull(row['Age']) or row['Age']<0:
        row['Age']=abs(np.random.normal(df_class.loc[row['Pclass'],'mean'],df_class.loc[row['Pclass'],'std'],1))
        return row['Age']
    return row['Age']
train['Age'] = train.apply(lambda x:generate_age(x ,df_class_train),axis=1)
test['Age'] = test.apply(lambda x:generate_age(x ,df_class_test),axis=1)

# %%
df_Pclass_d = pd.get_dummies(train['Pclass'],prefix='Pclass')
df_Embarked_d = pd.get_dummies(train['Embarked'],prefix='Embarked')
df_Cabin_d = pd.get_dummies(train['Cabin_Level'],prefix='Carbin')
df_Sex_d = pd.get_dummies(train['Sex'],prefix='sex')
train = train.drop(['Ticket','Pclass','Embarked','Cabin_Level','Sex'],axis=1)
train = pd.concat([train,df_Sex_d,df_Pclass_d,df_Embarked_d,df_Cabin_d],axis=1)

# %%
df_Pclass_d = pd.get_dummies(test['Pclass'],prefix='Pclass')
df_Embarked_d = pd.get_dummies(test['Embarked'],prefix='Embarked')
df_Cabin_d = pd.get_dummies(test['Cabin_Level'],prefix='Carbin')
df_Sex_d = pd.get_dummies(test['Sex'],prefix='sex')
test = test.drop(['Ticket','Pclass','Cabin_Level','Sex'],axis=1)
test = pd.concat([test,df_Sex_d,df_Pclass_d,df_Embarked_d,df_Cabin_d],axis=1)

# %%
test.head()
# Out:
#                                                      Name   Age     Fare  \
# PassengerId
# 892                                      Kelly, Mr. James  34.5   7.8292
# 893                      Wilkes, Mrs. James (Ellen Needs)    47   7.0000
# 894                             Myles, Mr. Thomas Francis    62   9.6875
# 895                                      Wirz, Mr. Albert    27   8.6625
# 896          Hirvonen, Mrs. Alexander (Helga E Lindqvist)    22  12.2875
#
#              accompanies_num  Is_Alone  sex_female  sex_male  Pclass_1  \
# PassengerId
# 892                        0         1           0         1         0
# 893                        1         0           1         0         0
# 894                        0         1           0         1         0
# 895                        0         1           0         1         0
# 896                        2         0           1         0         0
#
#              Pclass_2  Pclass_3  ...  Embarked_Q  Embarked_S  Carbin_A  \
# PassengerId                      ...
# 892                 0         1  ...           1           0         0
# 893                 0         1  ...           0           1         0
# 894                 1         0  ...           1           0         0
# 895                 0         1  ...           0           1         0
# 896                 0         1  ...           0           1         0
#
#              Carbin_B  Carbin_C  Carbin_D  Carbin_E  Carbin_F  Carbin_G  \
# PassengerId
# 892                 0         0         0         0         0         0
# 893                 0         0         0         0         0         0
# 894                 0         0         0         0         0         0
# 895                 0         0         0         0         0         0
# 896                 0         0         0         0         0         0
#
#              Carbin_None
# PassengerId
# 892                    1
# 893                    1
# 894                    1
# 895                    1
# 896                    1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Divide age into equal sized chunks

# %%
bins = [x*(1/9) for x in range(1,9)]
ranges = df['Age'].quantile(bins)
df.Age.max()
# Out:
# array([79.43491814])

# %%
train['Age_group'] = pd.cut(train['Age'], bins=[0,14,19,23,26,30,33,39,48,100],labels=[x for x in range(1,10)],include_lowest=True).astype(int)
test['Age_group'] = pd.cut(test['Age'], bins=[0,14,19,23,26,30,33,39,48,100],labels=[x for x in range(1,10)],include_lowest=True).astype(int)

# %%
train['Age_group'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Divide fare into equal sized chunks

# %%
bins = [x*(1/9) for x in range(1,10)]
ranges = df['Fare'].quantile(bins)

# %%
test['Fare'] = test['Fare'].fillna(test.median()['Fare'])

# %%
train['Fare_group'] = pd.cut(train['Fare'], bins=[0,7.73,7.85,8.66,13,16,26,34.5,73.5,513],labels=[x for x in range(1,10)],include_lowest=True).astype(int)
test['Fare_group'] = pd.cut(test['Fare'], bins=[0,7.73,7.85,8.66,13,16,26,34.5,73.5,513],labels=[x for x in range(1,10)],include_lowest=True).astype(int)

# %%
train.drop(['Fare','Age'],axis=1,inplace=True)
test.drop(['Fare','Age'],axis=1,inplace=True)

# %%
test.isnull().sum()
# Out:
# Name               0
# accompanies_num    0
# Is_Alone           0
# sex_female         0
# sex_male           0
# Pclass_1           0
# Pclass_2           0
# Pclass_3           0
# Embarked_C         0
# Embarked_Q         0
# Embarked_S         0
# Carbin_A           0
# Carbin_B           0
# Carbin_C           0
# Carbin_D           0
# Carbin_E           0
# Carbin_F           0
# Carbin_G           0
# Carbin_None        0
# Age_group          0
# Fare_group         0
# dtype: int64

# %% [markdown]
# ### Title out of names

# %%
train['Title']=train.Name.str.extract('([A-Za-z]+)\.',expand=False)
test['Title']=test.Name.str.extract('([A-Za-z]+)\.',expand=False)

# %%
dummies = [0 for _ in range(2)]
train['Title']=train['Title'].replace(['Col','Major','Jonkheer','Mme','Countess','Sir','Don','Capt','Lady','Rev'],'None')
train['Title']=train['Title'].replace(['Mlle','Ms'],'Miss')
dummies[0]=pd.get_dummies(train['Title'],prefix='title')
train=pd.concat([train.drop(['Title','Name'],axis=1),dummies[0]],axis=1)

test['Title']=test['Title'].replace(['Col','Major','Jonkheer','Mme','Countess','Sir','Don','Capt','Lady','Rev'],'None')
test['Title']=test['Title'].replace(['Mlle','Ms'],'Miss')
dummies[1]=pd.get_dummies(test['Title'],prefix='title')
test=pd.concat([test.drop(['Title','Name'],axis=1),dummies[1]],axis=1)

# %%
train['Fare_Age']=train['Fare_group']*train['Age_group']
test['Fare_Age']=test['Fare_group']*test['Age_group']

# %%
fare_age = train.groupby('Fare_Age').mean()['Survived']
plt.plot(fare_age)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
X_train = train.drop("Survived", axis=1)
Y_train = train["Survived"]

# %%
test.isnull().sum()
# Out:
# accompanies_num      0
# Is_Alone             0
# sex_female           0
# sex_male             0
# Pclass_1             0
# Pclass_2             0
# Pclass_3             0
# Embarked_C           0
# Embarked_Q           0
# Embarked_S           0
# Carbin_A             0
# Carbin_B             0
# Carbin_C             0
# Carbin_D             0
# Carbin_E             0
# Carbin_F             0
# Carbin_G             0
# Carbin_None          0
# Age_group            0
# Fare_group           0
# title_Dona           0
# title_Dr             0
# title_Master         0
# title_Miss           0
# title_Mr             0
# title_Mrs            0
# title_None           0
# Fare_Age           418
# dtype: int64

# %% [markdown]
# ### logistic regression

# %%
logreg = LogisticRegression(max_iter=1000)
logreg.fit(X_train, Y_train)
logreg.score(X_train,Y_train)*100
# Out:
# 83.80202474690664

# %%
coeff_df = pd.DataFrame(train.columns.delete(0))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logreg.coef_[0])

coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#             Feature  Correlation
# 22     title_Master     1.908987
# 2        sex_female     0.902291
# 14         Carbin_E     0.756656
# 13         Carbin_D     0.500936
# 25        title_Mrs     0.457828
# 4          Pclass_1     0.382557
# 11         Carbin_B     0.225158
# 5          Pclass_2     0.218671
# 7        Embarked_C     0.209265
# 15         Carbin_F     0.206449
# 20       Fare_group     0.112300
# 8        Embarked_Q     0.070057
# 27         Fare_Age     0.002544
# 23       title_Miss     0.000570
# 10         Carbin_A    -0.008223
# 19        Age_group    -0.102473
# 12         Carbin_C    -0.209755
# 1          Is_Alone    -0.241900
# 9        Embarked_S    -0.273947
# 18         Carbin_T    -0.309584
# 21         title_Dr    -0.384981
# 0   accompanies_num    -0.508283
# 16         Carbin_G    -0.519831
# 6          Pclass_3    -0.595853
# 17      Carbin_None    -0.636431
# 26       title_None    -0.818740
# 3          sex_male    -0.896916
# 24         title_Mr    -1.158290

# %% [markdown]
# ### SVM

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']} 
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)
grid.fit(X_train,Y_train)
grid.best_params_
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.618, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.618, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.618, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.618, total=   0.1s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.616, total=   0.1s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.663, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.635, total=   0.1s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.629, total=   0.1s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.640, total=   0.1s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.627, total=   0.0s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.601, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.635, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.635, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.640, total=   0.1s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.616, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.601, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.640, total=   0.0s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.624, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.640, total=   0.1s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.616, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.618, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.618, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.618, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.618, total=   0.1s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.616, total=   0.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.708, total=   0.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.669, total=   0.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.691, total=   0.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.708, total=   0.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.712, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.781, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.770, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.775, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.798, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.831, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.736, total=   0.1s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.742, total=   0.1s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.770, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.781, total=   0.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.825, total=   0.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.601, total=   0.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.680, total=   0.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.663, total=   0.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.685, total=   0.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.695, total=   0.1s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.601, total=   0.1s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.652, total=   0.1s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.629, total=   0.1s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.652, total=   0.1s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.616, total=   0.1s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.713, total=   0.1s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.674, total=   0.1s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.708, total=   0.1s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.719, total=   0.1s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.746, total=   0.2s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.758, total=   0.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.753, total=   0.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.770, total=   0.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.747, total=   0.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.802, total=   0.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.798, total=   0.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.803, total=   0.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.809, total=   0.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.809, total=   0.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.836, total=   0.1s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.826, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.809, total=   0.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.792, total=   0.1s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.764, total=   0.1s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.808, total=   0.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.640, total=   0.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.725, total=   0.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.708, total=   0.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.736, total=   0.0s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.746, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.713, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.674, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.708, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.719, total=   0.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.746, total=   0.1s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.770, total=   0.1s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.758, total=   0.1s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.736, total=   0.1s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.742, total=   0.1s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.797, total=   0.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.792, total=   0.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.775, total=   0.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.803, total=   0.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.787, total=   0.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.836, total=   0.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.831, total=   0.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.820, total=   0.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.809, total=   0.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.787, total=   0.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.859, total=   0.1s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.820, total=   0.0s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.803, total=   0.1s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.787, total=   0.1s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.764, total=   0.1s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.797, total=   0.1s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.713, total=   0.1s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.674, total=   0.1s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.708, total=   0.1s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.719, total=   0.1s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.746, total=   0.1s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.770, total=   0.1s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.758, total=   0.1s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.736, total=   0.1s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.742, total=   0.1s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.797, total=   0.1s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.758, total=   0.3s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.770, total=   0.3s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.787, total=   0.4s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.730, total=   0.2s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.825, total=   0.3s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.809, total=   0.2s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.803, total=   0.1s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.792, total=   0.2s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.798, total=   0.2s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.853, total=   0.2s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.831, total=   0.1s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.826, total=   0.1s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.815, total=   0.1s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.792, total=   0.1s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.853, total=   0.1s
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed:   10.3s finished
# {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
acc_svc = grid.score(X_train,Y_train)*100
acc_svc
# Out:
# 83.46456692913385

# %% [markdown]
# ### KNN

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
scaler.fit(X_train)
scaled_train = scaler.transform(X_train)
scaled_test = scaler.transform(test)

# %%
scores=[0]*39
for i in range(1,40):
    knn = KNN(n_neighbors=i)
    knn.fit(scaled_train,Y_train)
    scores[i-1]=round(knn.score(X_train, Y_train)*100,2)
plt.figure(figsize=(10,6))
plt.plot(range(1,40),scores,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Score vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn_final = KNN(n_neighbors=9)
knn_final.fit(scaled_train,Y_train)
score_knn=round(knn_final.score(X_train, Y_train)*100,2)
score_knn
# Out:
# 77.39

# %% [markdown]
# ### Gaussian

# %%
gaussian = GaussianNB()
gaussian.fit(X_train, Y_train)
score_gaussian = round(gaussian.score(X_train, Y_train) * 100, 2)
score_gaussian
# Out:
# 77.05

# %% [markdown]
# ### Perceptron

# %%
perceptron = Perceptron()
perceptron.fit(X_train, Y_train)
score_perceptron = round(perceptron.score(X_train, Y_train) * 100, 2)
score_perceptron
# Out:
# 62.77

# %% [markdown]
# ### Stochastic Gradient Descent

# %%
sgd = SGDClassifier()
sgd.fit(scaled_train, Y_train)
score_sgd = round(sgd.score(X_train, Y_train) * 100, 2)
score_sgd
# Out:
# 65.47

# %% [markdown]
# ### Decision Tree

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train,Y_train)
score_dtree = round(dtree.score(X_train, Y_train) * 100, 2)
score_dtree
# Out:
# 93.93

# %% [markdown]
# ### Random Forest

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)
score_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)
score_random_forest
# Out:
# 93.93

# %%
test['Survived'] = random_forest.predict(test)

# %%
test.head()
# Out:
#              accompanies_num  Is_Alone  sex_female  sex_male  Pclass_1  \
# PassengerId
# 892                        0         1           0         1         0
# 893                        1         0           1         0         0
# 894                        0         1           0         1         0
# 895                        0         1           0         1         0
# 896                        2         0           1         0         0
#
#              Pclass_2  Pclass_3  Embarked_C  Embarked_Q  Embarked_S  ...  \
# PassengerId                                                          ...
# 892                 0         1           0           1           0  ...
# 893                 0         1           0           0           1  ...
# 894                 1         0           0           1           0  ...
# 895                 0         1           0           0           1  ...
# 896                 0         1           0           0           1  ...
#
#              Fare_group  title_Dona  title_Dr  title_Master  title_Miss  \
# PassengerId
# 892                   2           0         0             0           0
# 893                   1           0         0             0           0
# 894                   4           0         0             0           0
# 895                   4           0         0             0           0
# 896                   4           0         0             0           0
#
#              title_Mr  title_Mrs  title_None  Fare_Age  Survived
# PassengerId
# 892                 1          0           0        14         0
# 893                 0          1           0         8         1
# 894                 1          0           0        36         0
# 895                 1          0           0        20         0
# 896                 0          1           0        12         1
#
# [5 rows x 29 columns]

# %%
test['PassengerId']=test.index

# %%
submission = pd.DataFrame({"PassengerId":test['PassengerId'],
                          "Survived":test['Survived']})

# %%
submission.to_csv("submission.csv",index=False)
